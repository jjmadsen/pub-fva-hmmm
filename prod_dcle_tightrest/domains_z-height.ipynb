# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7/openmm_dcle_tightrest/domains_z-height.csv', sep=',')
df2=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7/openmm_dcle_tightrest.2/domains_z-height.csv', sep=',')
df3=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7/openmm_dcle_tightrest.3/domains_z-height.csv', sep=',')

# %%
df3
# Out:
#       Frame       A1_z        A2_z       A3_z       C1_z       C2_z        FVa
# 0         0  90.964804  117.260733  82.864554  46.009222  38.697729  84.308432
# 1         1  90.921149  116.623633  82.858313  45.602133  38.744116  84.074774
# 2         2  91.286948  117.280524  83.191779  46.561407  39.651312  84.654227
# 3         3  91.210730  117.056143  82.646323  45.710043  38.920142  84.241614
# 4         4  90.568091  116.687125  82.234518  45.331274  38.493246  83.777258
# ...     ...        ...         ...        ...        ...        ...        ...
# 4995   4995  91.602454  111.632742  72.860800  38.125616  39.123831  79.483801
# 4996   4996  91.536246  111.595938  72.948203  38.707327  39.354315  79.595908
# 4997   4997  90.918082  110.837820  72.603491  38.060416  38.401556  78.929297
# 4998   4998  91.285971  111.214499  72.711935  38.431845  39.484000  79.316779
# 4999   4999  91.504507  110.962180  72.801611  38.624670  39.332785  79.331610
#
# [5000 rows x 7 columns]

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3, 1, gridspec_kw={'height_ratios': [1, 1, 1]}, figsize=(8, 6))
ax1.plot(df1.Frame,df1.A1_z,color='darkorange',label='A1')
ax1.plot(df1.Frame,df1.A2_z,color='gold',label='A2')
ax1.plot(df1.Frame,df1.A3_z,color='green',label='A3')
ax1.plot(df1.Frame,df1.C1_z,color='blue',label='C1')
ax1.plot(df1.Frame,df1.C2_z,color='red',label='C2')
ax1.plot(df1.Frame,df1.FVa,color='black',label='FVa')
ax2.plot(df1.Frame,df2.A1_z,color='darkorange',label='A1')
ax2.plot(df1.Frame,df2.A2_z,color='gold',label='A2')
ax2.plot(df1.Frame,df2.A3_z,color='green',label='A3')
ax2.plot(df1.Frame,df2.C1_z,color='blue',label='C1')
ax2.plot(df1.Frame,df2.C2_z,color='red',label='C2')
ax2.plot(df1.Frame,df2.FVa,color='black',label='FVa')
ax3.plot(df1.Frame,df3.A1_z,color='darkorange',label='A1')
ax3.plot(df1.Frame,df3.A2_z,color='gold',label='A2')
ax3.plot(df1.Frame,df3.A3_z,color='green',label='A3')
ax3.plot(df1.Frame,df3.C1_z,color='blue',label='C1')
ax3.plot(df1.Frame,df3.C2_z,color='red',label='C2')
ax3.plot(df1.Frame,df3.FVa,color='black',label='FVa')
ax2.set_ylabel("Domain or protein relative height, $z$ [$\AA$]",size=15)
ax3.set_xlabel("Simulation time [ns]",size=15)
ax1.set_ylim([0,120])
ax2.set_ylim([0,120])
ax3.set_ylim([0,120])
ax1.set_xticklabels([0,0,100,200,300,400,500])
ax2.set_xticklabels([0,0,100,200,300,400,500])
ax3.set_xticklabels([0,0,100,200,300,400,500])
ax1.set_yticks([0,20,40,60,80,100,120])
ax2.set_yticks([0,20,40,60,80,100,120])
ax3.set_yticks([0,20,40,60,80,100,120])
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
# Out:
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_1125/3610353348.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels([0,0,100,200,300,400,500])
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_1125/3610353348.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels([0,0,100,200,300,400,500])
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_1125/3610353348.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels([0,0,100,200,300,400,500])

# %%
fig.savefig('/Users/jespermadsen/Projects/FV-HMMM/figures/fva_domains_z-height/domains_z-height_aspect.pdf', bbox_inches='tight')

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1)
ax1.plot(df1.Frame,df1.A1_z,color='darkorange',label='A1')
ax1.plot(df1.Frame,df1.A2_z,color='gold',label='A2')
ax1.plot(df1.Frame,df1.A3_z,color='green',label='A3')
ax1.plot(df1.Frame,df1.C1_z,color='blue',label='C1')
ax1.plot(df1.Frame,df1.C2_z,color='red',label='C2')
ax1.plot(df1.Frame,df1.FVa,color='black',label='whole FVa')
ax2.plot(df1.Frame,df2.A1_z,color='darkorange',label='A1')
ax2.plot(df1.Frame,df2.A2_z,color='gold',label='A2')
ax2.plot(df1.Frame,df2.A3_z,color='green',label='A3')
ax2.plot(df1.Frame,df2.C1_z,color='blue',label='C1')
ax2.plot(df1.Frame,df2.C2_z,color='red',label='C2')
ax2.plot(df1.Frame,df2.FVa,color='black',label='whole FVa')
ax3.plot(df1.Frame,df3.A1_z,color='darkorange',label='A1')
ax3.plot(df1.Frame,df3.A2_z,color='gold',label='A2')
ax3.plot(df1.Frame,df3.A3_z,color='green',label='A3')
ax3.plot(df1.Frame,df3.C1_z,color='blue',label='C1')
ax3.plot(df1.Frame,df3.C2_z,color='red',label='C2')
ax3.plot(df1.Frame,df3.FVa,color='black',label='whole FVa')
ax2.set_ylabel("Domain or protein relative height, $z$ [$\AA$]")
ax3.set_xlabel("Simulation time [ns]")
ax1.set_ylim([0,120])
ax2.set_ylim([0,120])
ax3.set_ylim([0,120])
ax1.set_xlim([0,500])
ax2.set_xlim([0,500])
ax3.set_xlim([0,500])
ax1.set_xticklabels([0,10,20,30,40,50])
ax2.set_xticklabels([0,10,20,30,40,50])
ax3.set_xticklabels([0,10,20,30,40,50])
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_1125/3134974311.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels([0,10,20,30,40,50])
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_1125/3134974311.py:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels([0,10,20,30,40,50])
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_1125/3134974311.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels([0,10,20,30,40,50])
