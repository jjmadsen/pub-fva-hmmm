# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7_120apl/openmm_dcle_tightrest/domains_z-height.csv', sep=',')
df2=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7_120apl/openmm_dcle_tightrest.2/domains_z-height.csv', sep=',')
df3=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7_120apl/openmm_dcle_tightrest.3/domains_z-height.csv', sep=',')

# %%
df3
# Out:
#       Frame       A1_z        A2_z       A3_z       C1_z       C2_z        FVa
# 0         0  90.404593  116.126929  82.198798  45.346884  39.643149  83.726736
# 1         1  89.194022  114.930014  81.244803  44.333487  38.397055  82.554465
# 2         2  89.536902  114.859717  81.038962  44.525168  37.786993  82.517065
# 3         3  89.184775  114.231528  80.979285  43.944632  37.539297  82.152274
# 4         4  88.473898  113.628851  80.296835  43.080267  36.774100  81.454779
# ...     ...        ...         ...        ...        ...        ...        ...
# 4995   4995  81.592795   93.261526  69.872443  38.017859  37.547552  70.842245
# 4996   4996  81.771185   93.228918  69.761313  38.471487  37.923560  70.935233
# 4997   4997  82.257819   92.876990  69.769827  38.701422  38.437018  71.050665
# 4998   4998  81.927603   92.784109  69.561194  38.627570  37.629996  70.806265
# 4999   4999  82.589087   92.802023  70.044211  38.753973  37.497321  71.105338
#
# [5000 rows x 7 columns]

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1)
ax1.plot(df1.Frame,df1.A1_z,color='darkorange',label='A1')
ax1.plot(df1.Frame,df1.A2_z,color='gold',label='A2')
ax1.plot(df1.Frame,df1.A3_z,color='green',label='A3')
ax1.plot(df1.Frame,df1.C1_z,color='blue',label='C1')
ax1.plot(df1.Frame,df1.C2_z,color='red',label='C2')
ax1.plot(df1.Frame,df1.FVa,color='black',label='FVa')
ax2.plot(df1.Frame,df2.A1_z,color='darkorange',label='A1')
ax2.plot(df1.Frame,df2.A2_z,color='gold',label='A2')
ax2.plot(df1.Frame,df2.A3_z,color='green',label='A3')
ax2.plot(df1.Frame,df2.C1_z,color='blue',label='C1')
ax2.plot(df1.Frame,df2.C2_z,color='red',label='C2')
ax2.plot(df1.Frame,df2.FVa,color='black',label='FVa')
ax3.plot(df1.Frame,df3.A1_z,color='darkorange',label='A1')
ax3.plot(df1.Frame,df3.A2_z,color='gold',label='A2')
ax3.plot(df1.Frame,df3.A3_z,color='green',label='A3')
ax3.plot(df1.Frame,df3.C1_z,color='blue',label='C1')
ax3.plot(df1.Frame,df3.C2_z,color='red',label='C2')
ax3.plot(df1.Frame,df3.FVa,color='black',label='FVa')
ax2.set_ylabel("Domain or protein relative height, $z$ [$\AA$]",size=15)
ax3.set_xlabel("Simulation time [ns]",size=15)
ax1.set_ylim([0,120])
ax2.set_ylim([0,120])
ax3.set_ylim([0,120])
ax1.set_xticklabels([0,0,100,200,300,400,500])
ax2.set_xticklabels([0,0,100,200,300,400,500])
ax3.set_xticklabels([0,0,100,200,300,400,500])
ax1.set_yticks([0,20,40,60,80,100,120])
ax2.set_yticks([0,20,40,60,80,100,120])
ax3.set_yticks([0,20,40,60,80,100,120])
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_6711/620789266.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels([0,0,100,200,300,400,500])
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_6711/620789266.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels([0,0,100,200,300,400,500])
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_6711/620789266.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels([0,0,100,200,300,400,500])

# %%
fig.savefig('/Users/jespermadsen/Projects/FV-HMMM/figures/fva_domains_z-height/domains_z-height_120.pdf', bbox_inches='tight')

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1)
ax1.plot(df1.Frame,df1.A1_z,color='orange',label='A1')
ax1.plot(df1.Frame,df1.A2_z,color='yellow',label='A2')
ax1.plot(df1.Frame,df1.A3_z,color='green',label='A3')
ax1.plot(df1.Frame,df1.C1_z,color='blue',label='C1')
ax1.plot(df1.Frame,df1.C2_z,color='red',label='C2')
ax1.plot(df1.Frame,df1.FVa,color='black',label='FVa')
ax2.plot(df1.Frame,df2.A1_z,color='orange',label='A1')
ax2.plot(df1.Frame,df2.A2_z,color='yellow',label='A2')
ax2.plot(df1.Frame,df2.A3_z,color='green',label='A3')
ax2.plot(df1.Frame,df2.C1_z,color='blue',label='C1')
ax2.plot(df1.Frame,df2.C2_z,color='red',label='C2')
ax2.plot(df1.Frame,df2.FVa,color='black',label='FVa')
ax3.plot(df1.Frame,df3.A1_z,color='orange',label='A1')
ax3.plot(df1.Frame,df3.A2_z,color='yellow',label='A2')
ax3.plot(df1.Frame,df3.A3_z,color='green',label='A3')
ax3.plot(df1.Frame,df3.C1_z,color='blue',label='C1')
ax3.plot(df1.Frame,df3.C2_z,color='red',label='C2')
ax3.plot(df1.Frame,df3.FVa,color='black',label='FVa')
ax2.set_ylabel("Domain or protein relative height, $z$ [$\AA$]",size=15)
ax3.set_xlabel("Simulation time [ns]",size=15)
ax1.set_ylim([0,120])
ax2.set_ylim([0,120])
ax3.set_ylim([0,120])
ax1.set_xlim([0,500])
ax2.set_xlim([0,500])
ax3.set_xlim([0,500])
ax1.set_xticklabels([0,10,20,30,40,50])
ax2.set_xticklabels([0,10,20,30,40,50])
ax3.set_xticklabels([0,10,20,30,40,50])
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_2126/408119945.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels([0,10,20,30,40,50])
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_2126/408119945.py:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels([0,10,20,30,40,50])
# /var/folders/c8/mg5_rl016nl7jxykwhd6sn3c0000gn/T/ipykernel_2126/408119945.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels([0,10,20,30,40,50])
