# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
df1=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7_120apl/openmm_dcle_tightrest/spikes_z-height.csv', sep=',')
df2=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7_120apl/openmm_dcle_tightrest.2/spikes_z-height.csv', sep=',')
df3=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7_120apl/openmm_dcle_tightrest.3/spikes_z-height.csv', sep=',')

# %%
df3.head()
# Out:
#    Frame        S11        S12        S13        S14        S15        S16  \
# 0      0  19.321577  21.469138  16.699721  12.169684  14.130507  18.555540
# 1      1  18.475203  20.199133  15.914900  12.384299  15.081366  18.590468
# 2      2  19.884894  22.024191  17.725668  13.878485  15.990591  19.783179
# 3      3  20.234152  23.076056  18.252921  15.865309  16.698805  20.535223
# 4      4  20.492316  22.982214  18.358115  14.790457  16.396750  20.485510
#
#          S17        S18        S19  ...        S26        S27        S31  \
# 0  22.662802  23.634940  22.647192  ...  26.345740  27.507300  22.650107
# 1  22.857397  21.688895  21.872275  ...  26.375037  27.030875  22.438208
# 2  23.896048  23.528784  23.102332  ...  26.848807  28.008383  22.944952
# 3  24.748526  24.539557  23.574469  ...  27.245703  28.466147  23.238867
# 4  24.704382  24.761984  23.787741  ...  27.431174  28.755637  23.578635
#
# ...

# %%
fig, ax = plt.subplots()
ax.plot(df3.Frame[1000:5000],df3.S14[1000:5000])

# %%
total=pd.concat([df1.loc[1000:5000,df1.columns!='Frame'], df2.loc[1000:5000,df2.columns!='Frame'], df3.loc[1000:5000,df3.columns!='Frame']])
total
# Out:
#             S11        S12        S13        S14        S15        S16  \
# 1000  17.263022  18.094855  16.391028  11.574675  11.678328  16.928023
# 1001  17.516867  19.287375  17.421126  13.882399  14.905829  19.694250
# 1002  16.126128  17.898795  16.703070  12.292120  13.277190  18.499251
# 1003  15.816275  18.365279  16.324316  11.927138  13.526930  18.576582
# 1004  15.651198  18.826567  15.997069  12.036703  13.999197  18.963126
# ...         ...        ...        ...        ...        ...        ...
# 4895  21.163412  20.156447  18.208121  11.971144  12.967398  16.233542
# 4896  21.680869  20.835394  18.684187  12.609335  12.999922  16.773306
# 4897  22.543295  20.943869  19.596648  13.114432  14.369513  17.884337
# 4898  21.876639  20.819525  18.189047  12.269003  13.131255  16.889067
# 4899  21.311285  21.054861  18.473265  13.074011  13.163206  17.212828
#
#             S17        S18        S19        S21  ...        S26        S27  \
# ...

# %%
plt=seaborn.violinplot(total)
plt.set_xticklabels(plt.get_xticklabels(), rotation=45)
plt.set_ylabel('Relative height, $z$ [$\AA$]')
plt.set_xlabel('Spike residue')
plt.text(2.5,36,'Spike 1',c='orange')
plt.text(-0.5,40,'K')
plt.text(0.5,40,'K')
plt.text(1.5,40,'S')
plt.text(2.5,40,'W')
plt.text(3.5,40,'W')
plt.text(4.5,40,'G')
plt.text(5.5,40,'D')
plt.text(6.5,40,'Y')
plt.text(7.5,40,'W')

plt.text(10.5,36,'Spike 2',c='green')
plt.text(9,40,'Q')
plt.text(10,40,'G')
plt.text(11,40,'R')
plt.text(12,40,'V')
plt.text(13,40,'N')
plt.text(14,40,'A')
plt.text(14.7,40,'W')

plt.text(18.5,36,'Spike 3',c='purple')
plt.text(16,40,'C')
plt.text(17,40,'K')
plt.text(18,40,'S')
plt.text(19,40,'L')
plt.text(20,40,'S')
plt.text(21,40,'S')
plt.text(22,40,'E')
plt.text(23,40,'M')

plt.plot([8.5,8.5],[0,38],c='tab:blue')
plt.plot([15.5,15.5],[0,38],c='tab:blue')

plt.set_xticks(range(24),[2060,2061,2062,2063,2064,2065,2066,2067,2068,2078,2079,2080,2081,2082,2083,2084,2113,2114,2115,2116,2117,2118,2119,2129])

plt.figure.savefig('/Users/jespermadsen/Projects/FV-HMMM/figures/c2_spikes_z-height/spikes_z_new_120.pdf',bbox_inches='tight')

# %%
df4=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7/openmm_dcle_tightrest/spikes_z-height.csv', sep=',')
df5=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7/openmm_dcle_tightrest.2/spikes_z-height.csv', sep=',')
df6=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7/openmm_dcle_tightrest.3/spikes_z-height.csv', sep=',')
total=pd.concat([df1.loc[1000:5000,df1.columns!='Frame'], df2.loc[1000:5000,df2.columns!='Frame'], df3.loc[1000:5000,df3.columns!='Frame'],df4.loc[1000:5000,df4.columns!='Frame'],df5.loc[1000:5000,df5.columns!='Frame'],df6.loc[1000:5000,df6.columns!='Frame']])

# %%
plt=seaborn.violinplot(total)
plt.set_xticklabels(plt.get_xticklabels(), rotation=65)
plt.set_ylabel('Relative height, $z$ [$\AA$]',size=15)
plt.set_xlabel('Spike residues in C2',size=15)
plt.text(2.5,37,'Spike 1',c='orange')
plt.text(-0.3,41.5,'K')
plt.text(0.7,41.5,'K')
plt.text(1.7,41.5,'S')
plt.text(2.7,41.5,'W')
plt.text(3.7,41.5,'W')
plt.text(4.7,41.5,'G')
plt.text(5.7,41.5,'D')
plt.text(6.7,41.5,'Y')
plt.text(7.55,41.5,'W')

plt.text(11,37,'Spike 2',c='green')
plt.text(8.7,41.5,'Q')
plt.text(9.7,41.5,'G')
plt.text(10.7,41.5,'R')
plt.text(11.7,41.5,'V')
plt.text(12.7,41.5,'N')
plt.text(13.7,41.5,'A')
plt.text(14.55,41.5,'W')

plt.text(18.5,37,'Spike 3',c='purple')
plt.text(15.8,41.5,'C')
plt.text(16.8,41.5,'K')
plt.text(17.8,41.5,'S')
plt.text(18.8,41.5,'L')
plt.text(19.8,41.5,'S')
plt.text(20.8,41.5,'S')
plt.text(21.8,41.5,'E')
plt.text(22.8,41.5,'M')

plt.plot([8.5,8.5],[-1,43],c='tab:gray')
plt.plot([15.5,15.5],[-1,43],c='tab:gray')
plt.plot([-2,26],[18,18],c='red',linestyle='--',alpha=0.5)
plt.plot([-2,26],[20,20],c='blue',linestyle='--',alpha=0.5)
plt.plot([-2,26],[8,8],c='green',linestyle='--',alpha=0.5)
plt.text(24.3,6.5,'DCLE\nFWHM',c='green')
plt.text(24.3,17.5,'<P>',c='red')
plt.text(24.3,19.5,'<N>',c='blue')
#plt.plot(range(len(refplt1)),refplt1,c='silver',linestyle='-.')
#plt.plot(range(len(refplt2)),refplt2,c='khaki',linestyle='-')
#plt.plot(range(len(refplt3)),refplt3,c='olive',linestyle='--')
plt.plot()
plt.set_xticks(range(24),[2060,2061,2062,2063,2064,2065,2066,2067,2068,2078,2079,2080,2081,2082,2083,2084,2113,2114,2115,2116,2117,2118,2119,2120])

plt.set_xlim([-1,24])
plt.set_ylim([-1,43])
plt.figure.savefig('/Users/jespermadsen/Projects/FV-HMMM/figures/c2_spikes_z-height/spikes_z_new_allmemb.pdf',bbox_inches='tight')

# %%
ref1=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/analysis/open-closed-Xtal/spikes_z-height-1czv.csv')
ref2=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/analysis/open-closed-Xtal/spikes_z-height-1czs.csv')
ref3=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/analysis/open-closed-Xtal/spikes_z-height-1czt.csv')

# %%
refplt1=ref1.loc[:,ref1.columns!='Frame'].loc[0]
refplt2=ref2.loc[:,ref2.columns!='Frame'].loc[0]
refplt3=ref3.loc[:,ref3.columns!='Frame'].loc[0]

# %%
# C1 equivalent

# %%
df1=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7_120apl/openmm_dcle_tightrest/spikes_z-height_C1.csv', sep=',')
df2=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7_120apl/openmm_dcle_tightrest.2/spikes_z-height_C1.csv', sep=',')
df3=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7_120apl/openmm_dcle_tightrest.3/spikes_z-height_C1.csv', sep=',')
df4=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7/openmm_dcle_tightrest/spikes_z-height_C1.csv', sep=',')
df5=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7/openmm_dcle_tightrest.2/spikes_z-height_C1.csv', sep=',')
df6=pd.read_csv('/Users/jespermadsen/Projects/FV-HMMM/output_from_RRA/production_chlen7/openmm_dcle_tightrest.3/spikes_z-height_C1.csv', sep=',')
total=pd.concat([df1.loc[1000:5000,df1.columns!='Frame'], df2.loc[1000:5000,df2.columns!='Frame'], df3.loc[1000:5000,df3.columns!='Frame'],df4.loc[1000:5000,df4.columns!='Frame'],df5.loc[1000:5000,df5.columns!='Frame'],df6.loc[1000:5000,df6.columns!='Frame']])

# %%
plt=seaborn.violinplot(total)
plt.set_xticklabels(plt.get_xticklabels(), rotation=65)
plt.set_ylabel('Relative height, $z$ [$\AA$]',size=15)
plt.set_xlabel('Spike residues in C1',size=15)
plt.text(0.5,39,'Spike 1',c='orange')
plt.text(-0.3,41.5,'L')
plt.text(0.7,41.5,'G')
plt.text(1.7,41.5,'Y')
plt.text(2.65,41.5,'W')
plt.text(3.75,41.5,'G')
plt.text(4.7,41.5,'G')
plt.text(5.7,41.5,'S')
plt.text(6.7,41.5,'Y')
plt.text(7.7,41.5,'N')

plt.text(6.0,39,'Spike 2',c='green')
plt.text(8.7,41.5,'A')
plt.text(9.7,41.5,'W')
plt.text(10.75,41.5,'A')
plt.text(11.7,41.5,'K')
plt.text(12.7,41.5,'H')
plt.text(13.7,41.5,'Y')
plt.text(14.7,41.5,'L')

plt.text(14,39,'Spike 3',c='purple')
plt.text(15.8,41.5,'K')
plt.text(16.8,41.5,'S')
plt.text(17.8,41.5,'C')
#plt.text(18.8,40.5,'L')
#plt.text(19.8,40.5,'S')
#plt.text(20.8,40.5,'S')
#plt.text(21.8,40.5,'E')
#plt.text(22.8,40.5,'M')

plt.plot([3.5,3.5],[-1,43],c='tab:gray')
plt.plot([10.5,10.5],[-1,43],c='tab:gray')
plt.plot([-2,26],[18,18],c='red',linestyle='--',alpha=0.5)
plt.plot([-2,26],[20,20],c='blue',linestyle='--',alpha=0.5)
plt.plot([-2,26],[8,8],c='green',linestyle='--',alpha=0.5)
plt.text(19.3,6.5,'DCLE\nFWHM',c='green')
plt.text(19.3,17.5,'<P>',c='red')
plt.text(19.3,19.5,'<N>',c='blue')
#plt.plot(range(len(refplt1)),refplt1,c='silver',linestyle='-.')
#plt.plot(range(len(refplt2)),refplt2,c='khaki',linestyle='-')
#plt.plot(range(len(refplt3)),refplt3,c='olive',linestyle='--')
plt.plot()
plt.set_xticks(range(19),[1901,1902,1903,1904,1914,1915,1916,1917,1918,1919,1920,1953,1954,1955,1956,1957,1958,1959,1960])

plt.set_xlim([-1,19])
plt.set_ylim([-1,43])
plt.figure.savefig('/Users/jespermadsen/Projects/FV-HMMM/figures/c2_spikes_z-height/spikes_z_new_allmemb_C1.pdf',bbox_inches='tight')
